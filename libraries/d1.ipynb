# %%
import matplotlib.pyplot as plt
import numpy as np
gen=list(range(1,16))

# %%
#racetrack0
evol1=[5, 6, 16, 20, 24, 24, 24, 24, 24, 24, 24, 35, 35, 35, 40]
evol2=[5, 15, 24, 24, 24, 24, 24, 34, 34, 34, 34, 34, 34, 34, 37]
evol3=[4, 4, 4, 5, 5, 5, 26, 26, 94, 94, 94, 278, 308, 308, 308]
plt.plot(gen,evol1,label='mutation=0.04,choose_fittest=0.5')
plt.plot(gen,evol2,label='mutation=0.08,choose_fittest=0.3')
plt.plot(gen,evol3,label='mutation=0.16,choose_fittest=0.4')
plt.title('Racetrack 0')
plt.legend()

# %%
#racetrack1
evol1=[5, 6, 26, 26, 26, 26, 35, 35, 35, 40, 40, 40, 40, 40, 40]
evol2=[5, 15, 15, 20, 20, 20, 20, 79, 79, 136, 136, 136, 136,206, 206]
evol3=[20, 20, 34, 34, 34, 34, 45, 214, 214, 785, 785, 785, 785, 785, 785]
plt.plot(gen,evol1,label='mutation=0.04,choose_fittest=0.5')
plt.plot(gen,evol2,label='mutation=0.08,choose_fittest=0.3')
plt.plot(gen,evol3,label='mutation=0.16,choose_fittest=0.4')
plt.title('Racetrack 1')
plt.legend()

# %%
#racetrack2
evol1=[21, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133]
evol2=[20, 20, 20, 20, 33, 34, 34, 34, 56, 56, 106, 106, 106, 106, 106]
evol3=[24, 34, 55, 106, 106, 106, 106, 140, 255, 255, 255, 255, 275, 275, 275]
plt.plot(gen,evol1,label='mutation=0.04,choose_fittest=0.5')
plt.plot(gen,evol2,label='mutation=0.08,choose_fittest=0.3')
plt.plot(gen,evol3,label='mutation=0.16,choose_fittest=0.4')
plt.title('Racetrack 2')
plt.legend()

# %%
#racetrack3
evol1=[4, 29, 29, 29, 29, 29, 36, 36, 36, 36, 36, 42, 42, 42, 42]
evol2=[14, 25, 30, 30, 33, 36, 41, 41, 45, 45, 45, 72, 72, 72, 112]
evol3=[14, 14, 14, 14, 14, 14, 14, 26, 29, 29, 29, 29, 34, 34, 34]
plt.plot(gen,evol1,label='mutation=0.04,choose_fittest=0.5')
plt.plot(gen,evol2,label='mutation=0.08,choose_fittest=0.3')
plt.plot(gen,evol3,label='mutation=0.16,choose_fittest=0.4')
plt.title('Racetrack 3')
plt.legend()

# %%
#racetrack4
evol1=[8, 10, 87, 87, 87, 87, 87, 87, 87, 87, 106, 106, 148, 148, 202]
evol2=[22, 35, 46, 63, 63, 64, 79, 93, 93, 93, 93, 93, 93, 147, 158]
evol3=[11, 36, 40, 40, 64, 64, 64, 64, 64, 75, 75, 75, 75, 75, 75]
plt.plot(gen,evol1,label='mutation=0.04,choose_fittest=0.5')
plt.plot(gen,evol2,label='mutation=0.08,choose_fittest=0.3')
plt.plot(gen,evol3,label='mutation=0.16,choose_fittest=0.4')
plt.title('Racetrack 4')
plt.legend()
